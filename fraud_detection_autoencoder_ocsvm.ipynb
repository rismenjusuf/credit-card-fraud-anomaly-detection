# %% [markdown]
# <a href="https://colab.research.google.com/github/rismenjusuf/credit-card-fraud-anomaly-detection/blob/main/fraud_detection_autoencoder_ocsvm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
